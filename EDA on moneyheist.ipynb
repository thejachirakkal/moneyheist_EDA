# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import plotly as plot

# %%
heist=pd.read_csv("money heist - all seasons.csv.xls",encoding="latin-1")
heist
# Out:
#     Season   Episode                               Name     On Air  Year  \
# 0         1         1              Efectuar lo acordado  02-May-17  2017
# 1         1         2              Imprudencias letales  09-May-17  2017
# 2         1         3                           Misfire  16-May-17  2017
# 3         1         4                  Caballo de Troya  23-May-17  2017
# 4         1         5              El día de la marmota  30-May-17  2017
# 5         1         6             La cálida Guerra Fría  06-Jun-17  2017
# 6         1         7         Refrigerada inestabilidad  13-Jun-17  2017
# 7         1         8                 Tú lo has buscado  20-Jun-17  2017
# 8         1         9       El que la sigue la consigue  27-Jun-17  2017
# 9         2         1          Se acabaron las máscaras  16-Oct-17  2017
# 10        2         2                La cabeza del plan  23-Oct-17  2017
# 11        2         3              Cuestión de eficacia  02-Nov-17  2017
# ...

# %%
heist.shape
# Out:
# (41, 8)

# %%
heist.size
# Out:
# 328

# %%
heist.columns
# Out:
# Index(['Season ', 'Episode ', 'Name', 'On Air', 'Year', 'IMDB',
#        'Watch Time (minutes)', 'Summary'],
#       dtype='object')

# %%
heist.dtypes
# Out:
# Season                    int64
# Episode                   int64
# Name                     object
# On Air                   object
# Year                      int64
# IMDB                    float64
# Watch Time (minutes)      int64
# Summary                  object
# dtype: object

# %%
heist.isnull().sum()
# Out:
# Season                  0
# Episode                 0
# Name                    0
# On Air                  0
# Year                    0
# IMDB                    0
# Watch Time (minutes)    0
# Summary                 0
# dtype: int64

# %%
heist.describe().T
# Out:
#                       count         mean       std     min     25%     50%  \
# Season                 41.0     3.097561  1.496744     1.0     2.0     3.0
# Episode                41.0     4.707317  2.551900     1.0     3.0     5.0
# Year                   41.0  2018.951220  1.642425  2017.0  2017.0  2019.0
# IMDB                   41.0     8.178049  0.575114     7.1     7.8     8.3
# Watch Time (minutes)   41.0    49.292683  6.716561    41.0    43.0    50.0
#
#                          75%     max
# Season                   4.0     5.0
# Episode                  7.0    10.0
# Year                  2020.0  2021.0
# IMDB                     8.5     9.5
# Watch Time (minutes)    53.0    76.0

# %%
heist.head()
# Out:
#    Season   Episode                   Name     On Air  Year  IMDB  \
# 0        1         1  Efectuar lo acordado  02-May-17  2017   8.4
# 1        1         2  Imprudencias letales  09-May-17  2017   8.4
# 2        1         3               Misfire  16-May-17  2017   8.2
# 3        1         4      Caballo de Troya  23-May-17  2017   8.3
# 4        1         5  El día de la marmota  30-May-17  2017   8.4
#
#    Watch Time (minutes)                                            Summary
# 0                    47  The Professor recruits a young female robber a...
# 1                    41  Hostage negotiator Raquel makes initial contac...
# 2                    50  Police grab an image of the face of one of the...
# 3                    51  Raquel is adversely affected by a personal cri...
# 4                    42  A sudden development in the investigation and ...

# %%
heist.tail()
# Out:
#     Season   Episode                  Name     On Air  Year  IMDB  \
# 36        5         6         Escape Valve  03-Dec-21  2021   7.3
# 37        5         7     Wishful Thinking  03-Dec-21  2021   8.0
# 38        5         8  The Elegance Theory  03-Dec-21  2021   8.1
# 39        5         9          Pillow Talk  03-Dec-21  2021   8.5
# 40        5        10   A Family Tradition  03-Dec-21  2021   8.6
#
#     Watch Time (minutes)                                            Summary
# 36                    53  Sierra takes advantage of the Professor's grie...
# 37                    54  A break in the investigation and a mistake by ...
# 38                    50  Tamayo hunts for the gold as the team races ag...
# 39                    52  The Professor is left reeling after his tactic...
# 40                    76  With multiple lives on the line and Spain's ec...

# %%
heist.columns
# Out:
# Index(['Season ', 'Episode ', 'Name', 'On Air', 'Year', 'IMDB',
#        'Watch Time (minutes)', 'Summary'],
#       dtype='object')

# %%
heist[['Season ', 'Episode ']].groupby('Season ').count()
#this series have 5 season
# Out:
#          Episode
# Season
# 1               9
# 2               6
# 3               8
# 4               8
# 5              10

# %%
heist[['Season ', 'Watch Time (minutes)']].groupby('Season ').sum()
#total watch time in minutes for each season
# Out:
#          Watch Time (minutes)
# Season
# 1                         406
# 2                         279
# 3                         391
# 4                         402
# 5                         543

# %%
heist['On Air'].unique()
#money heist has started in '02-May-17' and ended in '03-Dec-21'
# Out:
# array(['02-May-17', '09-May-17', '16-May-17', '23-May-17', '30-May-17',
#        '06-Jun-17', '13-Jun-17', '20-Jun-17', '27-Jun-17', '16-Oct-17',
#        '23-Oct-17', '02-Nov-17', '09-Nov-17', '16-Nov-17', '23-Nov-17',
#        '19-Jul-19', '19-Jul-20', '19-Jul-21', '03-Apr-20', '03-Apr-21',
#        '03-Apr-22', '03-Sep-21', '03-Dec-21'], dtype=object)

# %%
heist['IMDB'].unique()
# Out:
# array([8.4, 8.2, 8.3, 8.7, 8.6, 8.5, 8.8, 9.4, 8.1, 9.5, 7.5, 7.2, 7.1,
#        7.7, 7.6, 7.3, 7.8, 8. ])

# %%
heist['IMDB'].nunique()
# Out:
# 18

# %%
#no of episodes  which got highest rating
heist[heist['IMDB']>=9]
#season 3 episode 8 has highest rating
# Out:
#     Season   Episode         Name     On Air  Year  IMDB  \
# 14        2         6  Bella ciao  23-Nov-17  2017   9.4
# 22        3         8      Astray  19-Jul-21  2019   9.5
#
#     Watch Time (minutes)                                            Summary
# 14                    43  After confessing a long-held secret, Moscow lo...
# 22                    60  Tokyo attempts to drown her sorrows. Sierra us...

# %%
heist[heist['IMDB']==9.5]['Summary'][22]
# Out:
# 'Tokyo attempts to drown her sorrows. Sierra uses personal tactics to target a vulnerable Nairobi, while Suárez continues to hunt down Raquel.'

# %%
heist.corr()
# Out:
# C:\Users\theja\AppData\Local\Temp\ipykernel_12064\4050765296.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heist.corr()
#                        Season   Episode       Year      IMDB  \
# Season                1.000000  0.105842  0.978272 -0.526029
# Episode               0.105842  1.000000  0.139662  0.327680
# Year                  0.978272  0.139662  1.000000 -0.580784
# IMDB                 -0.526029  0.327680 -0.580784  1.000000
# Watch Time (minutes)  0.496941  0.301214  0.490836  0.051539
#
#                       Watch Time (minutes)
# Season                            0.496941
# Episode                           0.301214
# Year                              0.490836
# IMDB                              0.051539
# Watch Time (minutes)              1.000000

# %%
heist['IMDB'].nlargest()
# Out:
# 22    9.5
# 14    9.4
# 11    8.8
# 12    8.8
# 13    8.8
# Name: IMDB, dtype: float64

# %%
heist['IMDB'].nsmallest()
# Out:
# 25    7.1
# 32    7.1
# 24    7.2
# 27    7.2
# 33    7.3
# Name: IMDB, dtype: float64

# %%
sns.boxplot(x="Season ",y="IMDB",data=heist)
# Out:
# <Axes: xlabel='Season ', ylabel='IMDB'>

# %%
heist.columns
# Out:
# Index(['Season ', 'Episode ', 'Name', 'On Air', 'Year', 'IMDB',
#        'Watch Time (minutes)', 'Summary'],
#       dtype='object')

# %%
sns.boxplot(x='Season ',y='Watch Time (minutes)',data=heist)
# Out:
# <Axes: xlabel='Season ', ylabel='Watch Time (minutes)'>

# %%
sns.barplot(x="Season ",y="Episode ",data=heist)
# Out:
# <Axes: xlabel='Season ', ylabel='Episode '>

# %%
sns.heatmap(heist.corr())
# Out:
# C:\Users\theja\AppData\Local\Temp\ipykernel_12064\1272111321.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(heist.corr())
# <Axes: >

# %%
heist[['Season ','IMDB','Watch Time (minutes)']].groupby('Season ').mean()
# Out:
#              IMDB  Watch Time (minutes)
# Season
# 1        8.366667             45.111111
# 2        8.816667             46.500000
# 3        8.450000             48.875000
# 4        7.612500             50.250000
# 5        7.860000             54.300000

# %%
heist[['Year','IMDB','Watch Time (minutes)']].groupby('Year').mean()
# Out:
#           IMDB  Watch Time (minutes)
# Year
# 2017  8.546667             45.666667
# 2019  8.450000             48.875000
# 2020  7.612500             50.250000
# 2021  7.860000             54.300000

# %%
heist[['Season ','Watch Time (minutes)']].groupby('Season ').sum()
# Out:
#          Watch Time (minutes)
# Season
# 1                         406
# 2                         279
# 3                         391
# 4                         402
# 5                         543

# %%
heist.style.highlight_max()
# Out:
# <style type="text/css">
# #T_dae3f_row4_col3, #T_dae3f_row12_col2, #T_dae3f_row22_col5, #T_dae3f_row31_col0, #T_dae3f_row31_col4, #T_dae3f_row32_col0, #T_dae3f_row32_col4, #T_dae3f_row33_col0, #T_dae3f_row33_col4, #T_dae3f_row34_col0, #T_dae3f_row34_col4, #T_dae3f_row35_col0, #T_dae3f_row35_col4, #T_dae3f_row36_col0, #T_dae3f_row36_col4, #T_dae3f_row37_col0, #T_dae3f_row37_col4, #T_dae3f_row38_col0, #T_dae3f_row38_col4, #T_dae3f_row39_col0, #T_dae3f_row39_col4, #T_dae3f_row40_col0, #T_dae3f_row40_col1, #T_dae3f_row40_col4, #T_dae3f_row40_col6, #T_dae3f_row40_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_dae3f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dae3f_level0_col0" class="col_heading level0 col0" >Season </th>
#       <th id="T_dae3f_level0_col1" class="col_heading level0 col1" >Episode </th>
#       <th id="T_dae3f_level0_col2" class="col_heading level0 col2" >Name</th>
# ...

# %%
heist.style.highlight_min()
# Out:
# <style type="text/css">
# #T_75038_row0_col0, #T_75038_row0_col1, #T_75038_row0_col3, #T_75038_row0_col4, #T_75038_row1_col0, #T_75038_row1_col4, #T_75038_row1_col6, #T_75038_row2_col0, #T_75038_row2_col4, #T_75038_row3_col0, #T_75038_row3_col4, #T_75038_row4_col0, #T_75038_row4_col4, #T_75038_row5_col0, #T_75038_row5_col4, #T_75038_row6_col0, #T_75038_row6_col4, #T_75038_row7_col0, #T_75038_row7_col4, #T_75038_row8_col0, #T_75038_row8_col4, #T_75038_row9_col1, #T_75038_row9_col4, #T_75038_row10_col4, #T_75038_row11_col4, #T_75038_row12_col4, #T_75038_row13_col4, #T_75038_row14_col4, #T_75038_row15_col1, #T_75038_row17_col2, #T_75038_row23_col1, #T_75038_row25_col5, #T_75038_row31_col1, #T_75038_row32_col5, #T_75038_row33_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_75038">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75038_level0_col0" class="col_heading level0 col0" >Season </th>
# ...
